# %%
from math import *

# %%
3!
# Out:
#   File "<ipython-input-3-eb65756f8b6d>", line 1
#     3!
#      ^
# SyntaxError: invalid syntax

# %%
n=100; k=35;
tl=[]
thr=[]
for t in range(n):
    thr=(t+1.)*(k+1.)/(n+2.)-1.
    print t,floor(thr),thr,ceil(thr)
# Out:
# 0 -1.0 -0.647058823529 -0.0
# 1 -1.0 -0.294117647059 -0.0
# 2 0.0 0.0588235294118 1.0
# 3 0.0 0.411764705882 1.0
# 4 0.0 0.764705882353 1.0
# 5 1.0 1.11764705882 2.0
# 6 1.0 1.47058823529 2.0
# 7 1.0 1.82352941176 2.0
# 8 2.0 2.17647058824 3.0
# 9 2.0 2.52941176471 3.0
# 10 2.0 2.88235294118 3.0
# 11 3.0 3.23529411765 4.0
# 12 3.0 3.58823529412 4.0
# 13 3.0 3.94117647059 4.0
# 14 4.0 4.29411764706 5.0
# 15 4.0 4.64705882353 5.0
# 16 5.0 5.0 5.0
# 17 5.0 5.35294117647 6.0
# 18 5.0 5.70588235294 6.0
# 19 6.0 6.05882352941 7.0
# 20 6.0 6.41176470588 7.0
# 21 6.0 6.76470588235 7.0
# 22 7.0 7.11764705882 8.0
# 23 7.0 7.47058823529 8.0
# 24 7.0 7.82352941176 8.0
# 25 8.0 8.17647058824 9.0
# 26 8.0 8.52941176471 9.0
# 27 8.0 8.88235294118 9.0
# 28 9.0 9.23529411765 10.0
# 29 9.0 9.58823529412 10.0
# 30 9.0 9.94117647059 10.0
# 31 10.0 10.2941176471 11.0
# 32 10.0 10.6470588235 11.0
# 33 11.0 11.0 11.0
# 34 11.0 11.3529411765 12.0
# 35 11.0 11.7058823529 12.0
# 36 12.0 12.0588235294 13.0
# ...
